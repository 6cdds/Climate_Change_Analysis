# %% [markdown]
# # Climate Change Data Analysis
#
# The goal of this project is to explore land temperature data in different areas over time, to assess the severity of climate change.

# %%
import pickle
import os
import sys
import pandas as pd
import numpy as np
import copy

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

# %reload_ext autoreload
# %autoreload 2
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Load data

with open('data/GlobalLandTemperaturesByCity.csv', 'r') as f:
    city_data = pd.read_csv(f)

# %% [markdown]
# ## Basic Data Exploration
#
# First we'll investigate the various variables in the data and do some cleaning.

# %%
city_data.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
city_data.shape
# Out:
# (8599212, 7)

# %%
city_data.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %% [markdown]
# The data is pretty self-explanatory - we have average temperatures with uncertainty for cities over time. We can convert the time column into datetime objects and parse the latitude and longitude (remove the direction and multiply by -1 for S and W)

# %%
city_data['time'] = pd.to_datetime(city_data['dt'], format='%Y-%m-%d')

# %%
'34.56S'.split('N')
# Out:
# ['34.56S']

# %%
def parse_lat_lon(val, t):
    if t == 'lat':
        if 'N' in val:

# %%
city_data.loc[np.array(['N' not in x for x in city_data['Latitude']]),:]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 78638    1841-01-01              21.432                          3.286
# 78639    1841-02-01              22.087                          2.458
# 78640    1841-03-01              18.859                          3.547
# 78641    1841-04-01              15.033                          1.884
# 78642    1841-05-01              12.864                          1.481
# 78643    1841-06-01              10.896                          1.479
# 78644    1841-07-01              10.172                          1.782
# 78645    1841-08-01              10.842                          1.485
# 78646    1841-09-01              12.147                          1.502
# 78647    1841-10-01              14.930                          1.607
# 78648    1841-11-01              17.544                          1.966
# 78649    1841-12-01              19.701                          1.898
# 78650    1842-01-01              21.626                          2.093
# 78651    1842-02-01              22.118                          2.191
# 78652    1842-03-01              20.604                          2.040
# 78653    1842-04-01              16.090                          2.554
# 78654    1842-05-01              12.692                          1.448
# 78655    1842-06-01              10.329                          1.446
# 78656    1842-07-01               9.272                          1.241
# 78657    1842-08-01              10.417                          1.468
# 78658    1842-09-01              12.150                          1.481
# 78659    1842-10-01              13.987                          1.973
# 78660    1842-11-01              17.570                          1.742
# 78661    1842-12-01              20.523                          2.269
# 78662    1843-01-01              22.374                          1.947
# 78663    1843-02-01              22.796                          1.917
# 78664    1843-03-01              19.809                          1.991
# 78665    1843-04-01              15.802                          1.998
# 78666    1843-05-01              12.501                          1.657
# 78667    1843-06-01              10.841                          1.550
# ...             ...                 ...                            ...
# 8488482  2011-04-01              26.562                          0.314
# 8488483  2011-05-01              26.198                          0.218
# 8488484  2011-06-01              25.567                          0.296
# 8488485  2011-07-01              25.061                          0.643
# 8488486  2011-08-01              25.091                          0.237
# 8488487  2011-09-01              25.958                          0.355
# 8488488  2011-10-01              26.124                          0.139
# 8488489  2011-11-01              26.924                          0.240
# 8488490  2011-12-01              27.404                          0.558
# 8488491  2012-01-01              27.842                          0.471
# 8488492  2012-02-01              28.043                          0.188
# 8488493  2012-03-01              27.761                          0.267
# 8488494  2012-04-01              26.722                          0.377
# 8488495  2012-05-01              25.881                          0.163
# 8488496  2012-06-01              25.288                          0.277
# 8488497  2012-07-01              24.566                          0.475
# 8488498  2012-08-01              25.020                          0.308
# 8488499  2012-09-01              25.856                          0.329
# 8488500  2012-10-01              26.340                          0.429
# 8488501  2012-11-01              27.193                          0.454
# 8488502  2012-12-01              27.639                          0.634
# 8488489  Zanzibar   Tanzania    5.63S    38.74E          2011-11-01
# 8488490  Zanzibar   Tanzania    5.63S    38.74E          2011-12-01
# 8488491  Zanzibar   Tanzania    5.63S    38.74E          2012-01-01
# 8488492  Zanzibar   Tanzania    5.63S    38.74E          2012-02-01
# 8488493  Zanzibar   Tanzania    5.63S    38.74E          2012-03-01
# 8488494  Zanzibar   Tanzania    5.63S    38.74E          2012-04-01
# 8488495  Zanzibar   Tanzania    5.63S    38.74E          2012-05-01
# 8488496  Zanzibar   Tanzania    5.63S    38.74E          2012-06-01
# 8488497  Zanzibar   Tanzania    5.63S    38.74E          2012-07-01
# 8488498  Zanzibar   Tanzania    5.63S    38.74E          2012-08-01
# 8488499  Zanzibar   Tanzania    5.63S    38.74E          2012-09-01
# 8488500  Zanzibar   Tanzania    5.63S    38.74E          2012-10-01
# 8488501  Zanzibar   Tanzania    5.63S    38.74E          2012-11-01
# 8488502  Zanzibar   Tanzania    5.63S    38.74E          2012-12-01
# 8488503  Zanzibar   Tanzania    5.63S    38.74E          2013-01-01
# 8488504  Zanzibar   Tanzania    5.63S    38.74E          2013-02-01
# 8488505  Zanzibar   Tanzania    5.63S    38.74E          2013-03-01
# 8488506  Zanzibar   Tanzania    5.63S    38.74E          2013-04-01
# 8488507  Zanzibar   Tanzania    5.63S    38.74E          2013-05-01
# 8488508  Zanzibar   Tanzania    5.63S    38.74E          2013-06-01
# 8488509  Zanzibar   Tanzania    5.63S    38.74E          2013-07-01
# 8488510  Zanzibar   Tanzania    5.63S    38.74E          2013-08-01
# 8488511  Zanzibar   Tanzania    5.63S    38.74E          2013-09-01
#
# [1276074 rows x 8 columns]

# %%
Looking at the number of cities and countires, we get the following:

# %%
cities = np.unique(city_data['City'])

# %%
countries = np.unique(city_data['Country'])

# %%
cities[cities == 'Toronto']
# Out:
# array(['Toronto'], dtype=object)

# %%
print 'Number of unique cities: ' + str(len(cities))
print 'Number of unique countries: ' + str(len(countries))
# Out:
# Number of unique cities: 3448
# Number of unique countries: 159

# %% [markdown]
# We'll look at the distribution of cities on a map:

# %%
#unique_city_data = city_data.groupby('City').first()

mpis = [{'lat': ['34.56S'],
  'lon': ['138.16'],
  'marker': {'color': 'rgb(0,116,217)',
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 38.700000000000003,
   'sizemode': 'diameter'},
  'text': '0.387',
  'type': 'scattergeo'},
]


layout = go.Layout(
    title = 'MPI',
    showlegend = True,
    geo = dict(
            scope='world',
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=mpis)
iplot( fig, validate=False)
# Out:
# <div id="9e7be96d-bc4d-4e3a-9f5d-03f173280163" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e7be96d-bc4d-4e3a-9f5d-03f173280163", [{"lat": ["34.56S"], "text": "0.387", "type": "scattergeo", "marker": {"color": "rgb(0,116,217)", "line": {"color": "rgb(40,40,40)", "width": 0.5}, "sizemode": "diameter", "size": 38.7}, "lon": ["138.16"]}], {"showlegend": true, "geo": {"showland": true, "countrycolor": "rgb(255, 255, 255)", "projection": {"type": "natural earth"}, "subunitwidth": 1, "countrywidth": 1, "landcolor": "rgb(217, 217, 217)", "subunitcolor": "rgb(255, 255, 255)", "scope": "world"}, "title": "MPI"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
