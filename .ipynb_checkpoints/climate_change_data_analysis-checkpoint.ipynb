# %% [markdown]
# # Climate Change Data Analysis
#
# The goal of this project is to explore land temperature data in different areas over time, to assess the severity of climate change.

# %%
import pickle
import os
import sys
import pandas as pd
import numpy as np
import copy

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

# %reload_ext autoreload
# %autoreload 2
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Load data

with open('data/GlobalLandTemperaturesByCity.csv', 'r') as f:
    city_data = pd.read_csv(f)

# %% [markdown]
# ## Data Cleaning
#
# First we'll investigate the various variables in the data and do some cleaning.

# %%
city_data.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
city_data.shape
# Out:
# (8599212, 7)

# %%
city_data.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %% [markdown]
# The data is pretty self-explanatory - we have average temperatures with uncertainty for cities over time. We can convert the time column into datetime objects and parse the latitude and longitude (remove the direction and multiply by -1 for S and W)

# %%
city_data['time'] = pd.to_datetime(city_data['dt'], format='%Y-%m-%d')

# %%
'34.56S'.split('N')
# Out:
# ['34.56S']

# %%
def parse_lat_lon(val, t):
    if t == 'lat':
        if 'N' in val:
            return float(val.split('N')[0])
        elif 'S' in val:
            return -1 * float(val.split('S')[0])
        else:
            return np.nan
    else:
        if 'E' in val:
            return float(val.split('E')[0])
        elif 'W' in val:
            return -1 * float(val.split('W')[0])
        else:
            return np.nan

# %%
city_data['Latitude'] = map(lambda x: parse_lat_lon(x, 'lat'),city_data['Latitude'])
city_data['Longitude'] = map(lambda x: parse_lat_lon(x, 'lon'),city_data['Longitude'])

# %% [markdown]
# ## Data Exploration
#
# Now we'll look into the data further. Looking at the number of cities and countires, we get the following:

# %%
cities = np.unique(city_data['City'])
countries = np.unique(city_data['Country'])

# %%
print 'Number of unique cities: ' + str(len(cities))
print 'Number of unique countries: ' + str(len(countries))
# Out:
# Number of unique cities: 3448
# Number of unique countries: 159

# %% [markdown]
# We'll look at the distribution of cities on a map:

# %%
unique_city_data = city_data.groupby('City').first()

# %%
mpis = [{'lat': unique_city_data['Latitude'],
  'lon': unique_city_data['Longitude'],
  'marker': {'color': 'rgb(0,116,217)',
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 5,
   'sizemode': 'diameter'},
  'text': unique_city_data.index,
  'type': 'scattergeo'},
]


layout = go.Layout(
    title = 'City Distribution',
    showlegend = True,
    geo = dict(
            scope='world',
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=mpis)
iplot( fig, validate=False)

# %% [markdown]
# Now we look at the amount of temperature data we have for each city - i.e. the distribution of the start year, end year and average sampling rate.

# %%
n = city_data.isnull().none(axis=1)
clean_data = city_data.loc[n.index[n],:]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-105-d56851ae86ca> in <module>()
# ----> 1 n = city_data.isnull().none(axis=1)
#       2 clean_data = city_data.loc[n.index[n],:]
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\generic.pyc in isnull(self)
#    4196     @Appender(_shared_docs['isnull'])
#    4197     def isnull(self):
# -> 4198         return isnull(self).__finalize__(self)
#    4199
#    4200     _shared_docs['isnotnull'] = """
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\dtypes\missing.pyc in isnull(obj)
#      42     pandas.notnull: boolean inverse of pandas.isnull
#      43     """
# ---> 44     return _isnull(obj)
#      45
#      46
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\dtypes\missing.pyc in _isnull_new(obj)
#      54         return _isnull_ndarraylike(obj)
#      55     elif isinstance(obj, ABCGeneric):
# ---> 56         return obj._constructor(obj._data.isnull(func=isnull))
#      57     elif isinstance(obj, list) or hasattr(obj, '__array__'):
#      58         return _isnull_ndarraylike(np.asarray(obj))
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\internals.pyc in isnull(self, **kwargs)
#    3189
#    3190     def isnull(self, **kwargs):
# -> 3191         return self.apply('apply', **kwargs)
#    3192
#    3193     def where(self, **kwargs):
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3096         bm = self.__class__(result_blocks, axes or self.axes,
#    3097                             do_integrity_check=do_integrity_check)
# -> 3098         bm._consolidate_inplace()
#    3099         return bm
#    3100
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\internals.pyc in _consolidate_inplace(self)
#    3576     def _consolidate_inplace(self):
#    3577         if not self.is_consolidated():
# -> 3578             self.blocks = tuple(_consolidate(self.blocks))
#    3579             self._is_consolidated = True
#    3580             self._known_consolidated = True
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\internals.pyc in _consolidate(blocks)
#    4523     for (_can_consolidate, dtype), group_blocks in grouper:
#    4524         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4525                                       _can_consolidate=_can_consolidate)
#    4526         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4527     return new_blocks
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\internals.pyc in _merge_blocks(blocks, dtype, _can_consolidate)
#    4546
#    4547         argsort = np.argsort(new_mgr_locs)
# -> 4548         new_values = new_values[argsort]
#    4549         new_mgr_locs = new_mgr_locs[argsort]
#    4550
#
# MemoryError:

# %%
clean_data.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
# 9  1744-08-01                 NaN                            NaN  Århus
#
#    Country  Latitude  Longitude                time
# 1  Denmark     57.05      10.33 1743-12-01 00:00:00
# 2  Denmark     57.05      10.33 1744-01-01 00:00:00
# 3  Denmark     57.05      10.33 1744-02-01 00:00:00
# 4  Denmark     57.05      10.33 1744-03-01 00:00:00
# 9  Denmark     57.05      10.33 1744-08-01 00:00:00

# %%
time_stats = city_data.groupby('City').agg({'time': {'start_year': lambda x: min(x.loc[x.loc['AverageTemperature'].notnull()]).year, 
                                                     'end_year': lambda x: max(x.loc[x.loc[:, 'AverageTemperature'].notnull()]).year, 
                                                     'ave_samp_rate': lambda x: x.loc[x.loc[:, 'AverageTemperature'].notnull()].diff().mean().total_seconds() / 3600.0,
                                                       'num_samps': 'count'}})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-92-f803360bfaf4> in <module>()
#       2                                                      'end_year': lambda x: max(x.loc[x.loc[:, 'AverageTemperature'].notnull(),:]).year,
#       3                                                      'ave_samp_rate': lambda x: x.loc[x.loc[:, 'AverageTemperature'].notnull(),:].diff().mean().total_seconds() / 3600.0,
# ----> 4                                                        'num_samps': 'count'}})
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    4034         versionadded=''))
#    4035     def aggregate(self, arg, *args, **kwargs):
# -> 4036         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4037
#    4038     agg = aggregate
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3466
#    3467         _level = kwargs.pop('_level', None)
# -> 3468         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3469         if how is None:
#    3470             return result
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\base.pyc in _aggregate(self, arg, *args, **kwargs)
#     531             # nested renamer
#     532             if is_nested_renamer:
# --> 533                 result = list(_agg(arg, _agg_1dim).values())
#     534
#     535                 if all(isinstance(r, dict) for r in result):
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\base.pyc in _agg(arg, func)
#     522                 result = compat.OrderedDict()
#     523                 for fname, agg_how in compat.iteritems(arg):
# --> 524                     result[fname] = func(fname, agg_how)
#     525                 return result
#     526
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\base.pyc in _agg_1dim(name, how, subset)
#     505                     raise SpecificationError("nested dictionary is ambiguous "
#     506                                              "in aggregation")
# --> 507                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     508
#     509             def _agg_2dim(name, how):
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, func_or_funcs, *args, **kwargs)
#    2871         if hasattr(func_or_funcs, '__iter__'):
#    2872             ret = self._aggregate_multiple_funcs(func_or_funcs,
# -> 2873                                                  (_level or 0) + 1)
#    2874         else:
#    2875             cyfunc = self._is_cython_func(func_or_funcs)
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _aggregate_multiple_funcs(self, arg, _level)
#    2944                 obj._reset_cache()
#    2945                 obj._selection = name
# -> 2946             results[name] = obj.aggregate(func)
#    2947
#    2948         if isinstance(list(compat.itervalues(results))[0],
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, func_or_funcs, *args, **kwargs)
#    2883                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2884             except Exception:
# -> 2885                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2886
#    2887             index = Index(sorted(result), name=self.grouper.names[0])
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _aggregate_named(self, func, *args, **kwargs)
#    3011         result = {}
#    3012
# -> 3013         for name, group in self:
#    3014             group.name = name
#    3015             output = func(group, *args, **kwargs)
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in get_iterator(self, data, axis)
#    1753         for each group
#    1754         """
# -> 1755         splitter = self._get_splitter(data, axis=axis)
#    1756         keys = self._get_group_keys()
#    1757         for key, (i, group) in zip(keys, splitter):
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _get_splitter(self, data, axis)
#    1759
#    1760     def _get_splitter(self, data, axis=0):
# -> 1761         comp_ids, _, ngroups = self.group_info
#    1762         return get_splitter(data, comp_ids, ngroups, axis=axis)
#    1763
#
# pandas/_libs/src\properties.pyx in pandas._libs.lib.cache_readonly.__get__()
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in group_info(self)
#    1871     @cache_readonly
#    1872     def group_info(self):
# -> 1873         comp_ids, obs_group_ids = self._get_compressed_labels()
#    1874
#    1875         ngroups = len(obs_group_ids)
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _get_compressed_labels(self)
#    1878
#    1879     def _get_compressed_labels(self):
# -> 1880         all_labels = [ping.labels for ping in self.groupings]
#    1881         if len(all_labels) > 1:
#    1882             group_index = get_group_index(all_labels, self.shape,
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in labels(self)
#    2531     def labels(self):
#    2532         if self._labels is None:
# -> 2533             self._make_labels()
#    2534         return self._labels
#    2535
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _make_labels(self)
#    2543         if self._labels is None or self._group_index is None:
#    2544             labels, uniques = algorithms.factorize(
# -> 2545                 self.grouper, sort=self.sort)
#    2546             uniques = Index(uniques, name=self.name)
#    2547             self._labels = labels
#
# C:\Users\colleen.s\Anaconda2\lib\site-packages\pandas\core\algorithms.pyc in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.get_labels()
#
# MemoryError:

# %%
time_stats.columns = ['end_year', 'start_year', 'num_samps', 'ave_samp_rate']

# %%
print 'Number of unique start years: ' + str(len(np.unique(time_stats['start_year'])))
print 'Number of unique end years: ' + str(len(np.unique(time_stats['end_year'])))
# Out:
# Number of unique start years: 65
# Number of unique end years: 1

# %% [markdown]
# All data collection appears to end in the same year:

# %%
print time_stats['end_year'].iloc[0]
# Out:
# 2013

# %% [markdown]
# Below we plot histograms for the start year, number of samples and average sampling rate:

# %%
iplot(go.Figure(data = [go.Histogram(x = time_stats['start_year'])],
               layout = go.Layout(title = 'Distribution of Start Year of Temp Samples')))
# Out:
# <div id="92fa2ef0-7af5-4dda-a306-b6783203ac23" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
928787224859, 730.4822134387351, 730.4879555281037, 730.4917431192662, 730.4917431192662, 730.4978250362495, 730.4928787224859, 730.4845360824743, 730.4879555281037, 730.4826254826254, 730.4826254826254, 730.5027124773959, 730.4913627639155, 730.4977511244379, 730.4812239221139, 730.4823529411765, 730.4817813765181, 730.4822134387351, 730.5094736842107, 730.4823529411765, 730.4879555281037, 730.4817813765181, 730.4928787224859, 730.4917431192662, 730.4879555281037, 730.4840989399293, 730.5014191106906, 730.4917431192662, 730.4861012116892, 730.4839203675344, 730.4917431192662, 730.4879555281037, 730.4917431192662, 730.4897260273972, 730.4917431192662, 730.4917431192662, 730.4917431192662, 730.4917431192662, 730.4917431192662, 730.4917431192662, 730.4925619834712, 730.5094736842107, 730.5094736842107, 730.4840989399293, 730.4879555281037, 305.1705914075139, 730.4879555281037, 730.4840989399293, 730.4879555281037, 730.4847250509164, 730.4922547332187, 730.4879555281037, 730.4879555281037, 730.4885496183206, 730.4822134387351, 730.4839203675344, 730.4823529411765, 730.4897260273972, 730.4920699471328, 730.4822134387351, 730.4920699471328, 730.4899777282851, 730.4925619834712, 730.4840989399293, 730.4861012116892, 730.4917431192662, 730.4897260273972, 730.4897260273972, 730.4808184143224, 730.4917431192662, 730.4879555281037, 730.4822134387351, 730.4861012116892, 730.4813278008297, 730.4879555281037, 730.4839203675344, 342.6137704918031, 730.4922547332187, 730.4839203675344, 730.4847250509164, 730.4904862579282, 730.5094736842107, 730.48409 ...

# %% [markdown]
# The data collection beings for each city somewhere in the 1700s or 1800s and ends in 2013.  The vast majority of cities were sampled about one a month (~730 hours), some had higher sampling rates but not lower than once a month.  Thus, the majority of cities had about 2000-3000 total temperature samples and the cities with higher sampling rates had up to 9000 samples.
#
# This is good since we'll be able to get temperature trends over 200 or so years and likely be able to remove seasonal variations. In addition, we can get these trends for many cities around the world and compare them.
#
# Given this, we can refine our goal for this analysis to be to assess the rate of change of temperature over the last 200 years for cities around the world and the planet as a whole.  We will also attempt to predict the year where temperatures will hit 2C and 4C above pre-industrial levels.
#
# **Insert info about why 2C and 4C chosen**

# %% [markdown]
# ## Trend Analysis
#
# Now we'll investigate any trends present in the temperature data.  First we'll plot the temperature over time for a few cities around the world.  This paper: http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.491.295&rep=rep1&type=pdf identifies a representative major city for each climate type:
#
# Singapore (tropical)
# Cairo, Egypt (hot-arid)
# Milan, Italy (temperate)
# Fort Smith, Canada (cold)
# Resolute (polar)
#
# We don't have info for Fort Smith and Resolute - and in fact no information for any polar areas.  So we'll just look at Norilsk, Russia for a cold climate, even though the climate is actually both cold and temperate (https://en.climate-data.org/asia/russian-federation/krasnoyarsk-krai/norilsk-1831/)

# %%
data = city_data.loc[city_data['City'] == 'Singapore',:]
iplot(go.Figure(data = [go.Scatter(x = data['time'], y = data['AverageTemperature'])], 
                layout = go.Layout(title = 'Temperature of Singapore Over Time')))
# Out:
# <div id="06085075-582f-4687-812f-5859c2fa660a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("06085075-582f-4687-812f-5859c2fa660a", [{"y": [25.332, 25.549000000000003, 26.285, 26.999000000000002, 27.45000000000001, 27.73200000000001, 27.765, 26.399, 26.143, 26.04000000000001, 26.249, 25.160999999999998, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null,